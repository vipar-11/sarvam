# %% [markdown]
# # Hello World

# %%
import os
from dotenv import load_dotenv

# %% [markdown]
# ## Setup / Load the API key

# %%
load_dotenv()
SARVAM_API_KEY=os.getenv("SARVAM_API_KEY")

# %% [markdown]
# ## Make the first API call

# %%
from sarvamai import SarvamAI

client = SarvamAI(
    api_subscription_key=SARVAM_API_KEY
)

# %%
response = client.chat.completions(
    model="sarvam-105b-conversations",
    messages=[
        {
            "role" : "user",
            "content" : "Hi, How are  you? Ask this query in all supported Indian languages"
        }
    ],
)

print(response.choices[0].message.content)
# Out:
# Here are the ways to ask “Hi, how are you?” in all 22 official Indian languages:
#
# 1. **Assamese:** নমস্কাৰ, আপুনি কেনে আছে?
# 2. **Bengali:** নমস্কার, আপনি কেমন আছেন?
# 3. **Bodo:** बरायबाय, नोंथाङा माबोरै दं?
# 4. **Dogri:** नमस्ते, तुस कियां ओ?
# 5. **Gujarati:** નમસ્તે, તમે કેમ છો?
# 6. **Hindi:** नमस्ते, आप कैसे हैं?
# 7. **Kannada:** ನಮಸ್ಕಾರ, ನೀವು ಹೇಗಿದ್ದೀರಿ?
# 8. **Kashmiri:** नमस्कार, तुही कियाह चھیव?
# 9. **Konkani:** नमस्कार, तुमकां कशे आसात?
# 10. **Maithili:** नमस्कार, अहाँ केहन छी?
# 11. **Malayalam:** നമസ്കാരം, നിങ്ങൾ സുഖമായിരിക്കുകയാണോ?
# 12. **Manipuri (Meitei):** ꯈꯨꯔꯨꯝꯖꯔꯤ, ꯅꯈoyদিং করম তৌরি?
# 13. **Marathi:** नमस्कार, तुम्ही कसे आहात?
# 14. **Nepali:** नमस्ते, तपाईं कस्तो छौ?
# 15. **Odia:** ନମସ୍କାର, ଆପଣ କେମିତି ଅଛନ୍ତି?
# 16. **Punjabi:** ਨਮਸਤੇ, ਤੁਸੀਂ ਕਿਵੇਂ ਹੋ?
# 17. **Sanskrit:** नमस्ते, भवान् कथम् अस्ति?
# 18. **Santali:** ᱱᱚᱢᱚᱥᱠᱟᱨ, ᱟᱢ ᱪᱮᱫ ᱞᱮᱠᱟ ᱢᱮᱱᱟᱢᱟ?
# 19. **Sindhi:** نمستي، تون ڪيئن آهين؟
# 20. **Tamil:** வணக்கம், நீங்கள் எப்படி இருக்கிறீர்கள்?
# 21. **Telugu:** నమస్కారం, మీరు ఎలా ఉన్నారు?
# 22. **Urdu:** नमस्ते, آپ کیسے ہیں?
#
# If you’d like, I can also provide these in **Roman script** or with **transliteration** so you can read and pronounce them easily.

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "20260925_cf673763-dfc9-4d5f-9e8d-5bddeb25a5f4",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "Hi! I’m doing well, thanks for asking. How about you—what’s on your mind today?",
#         "role": "assistant",
#         "refusal": null,
#         "reasoning_content": null,
#         "tool_calls": null
#       },
#       "logprobs": null
#     }
#   ],
#   "created": 1790351091,
#   "model": "sarvam-105b-conversations",
#   "object": "chat.completion",
#   "system_fingerprint": "vllm-0.29.1rc1.dev145+gfe61f3317-9c902b0a",
#   "usage": {
#     "completion_tokens": 25,
#     "prompt_tokens": 20,
#     "total_tokens": 45,
#     "completion_tokens_details": null,
#     "prompt_tokens_details": null
#   },
#   "service_tier": null
# }
