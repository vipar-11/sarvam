# %% [markdown]
# # Using the Open AI Interface

# %%
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Setup API Keys

# %%
load_dotenv()
SARVAM_API_KEY = os.getenv('SARVAM_API_KEY')

assert SARVAM_API_KEY is not None, 'Could NOT load SARVAM_API_KEY from .env'

# %% [markdown]
# ## Make your first API Call

# %%
#from sarvamai import SarvamAI
from openai import OpenAI

# %%
# client = SarvamAI(
#     api_subscription_key=SARVAM_API_KEY,
# )

client = OpenAI(
    base_url="https://api.sarvam.ai/v1",
    api_key=SARVAM_API_KEY,
)

response = client.chat.completions.create(
    model="sarvam-105b-conversations",
    messages=[
        {"role": "user", "content": "Hi, How are you?"},
    ],
)
print(response.choices[0].message.content)
# Out:
# Hi! I’m doing well, thanks for asking. How about you—how’s your day going?

# %% [markdown]
# ## Use Different Models with the same code

# %%
def call_llm(base_url, api_key, model):
    
    client = OpenAI(
        base_url=base_url,
        api_key=api_key,
    )

    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": "Hi, How are you?"},
        ],
    )
    
    print(response.choices[0].message.content)

# %% [markdown]
# ### Call using SarvamAI

# %%
call_llm(
    "https://api.sarvam.ai/v1", 
    SARVAM_API_KEY, 
    "sarvam-105b-conversations"
)
# Out:
# Hi! I’m doing well, thanks for asking. How about you—what’s on your mind today?

# %% [markdown]
# ### Call using Groq

# %%
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

call_llm(
    "https://api.groq.com/openai/v1", 
    GROQ_API_KEY, 
    "openai/gpt-oss-120b"
)
# Out:
# Hello! I'm doing great, thank you for asking. How can I help you today?
