# %% [markdown]
# # Document Digitization

# %%
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Setup API Keys

# %%
load_dotenv()
SARVAM_API_KEY = os.getenv('SARVAM_API_KEY')

assert SARVAM_API_KEY is not None, 'Could NOT load SARVAM_API_KEY from .env'

# %%
from sarvamai import SarvamAI
# from sarvamai.core.api_error import ApiError

# %%
client = SarvamAI(
    api_subscription_key=SARVAM_API_KEY,
)

# %% [markdown]
# ## Digitize handwritten document (English)

# %%
def load_document(f_name: str):
    with open(f_name, 'rb') as f_in:
        return f_in.read()

# %%
data = load_document('./data/pdfs/feedback_notes.pdf')

# %% [markdown]
# ### Submit Job

# %%
job = client.doc_ai.digitise(
    file=[('output', data, 'application/pdf')],
    language='en-IN',
    output_format='md'
)

# %%
job.job_id
# Out:
# '01a0bee2-1396-7cef-bc37-7c1b79aa4a01'

# %% [markdown]
# ### Check Job Status

# %%
status = client.doc_ai.get_status(job_id=job.job_id)
status
# Out:
# DocAiJobStatusResponse(job_id='01a0bee2-1396-7cef-bc37-7c1b79aa4a01', status='completed', pipeline='digitise', usage=DocAiUsage(pages_total=6, pages_processed=6, pages_succeeded=6, pages_failed=0), created_at='2026-09-20T12:54:42Z', updated_at='2026-09-20T12:54:44Z', $schema='https://api.sarvam.ai/schemas/PublicJobBody.json')

# %%
import json

json.loads(status.json())
# Out:
# {'job_id': '01a0bee2-1396-7cef-bc37-7c1b79aa4a01',
#  'status': 'completed',
#  'pipeline': 'digitise',
#  'usage': {'pages_total': 6,
#   'pages_processed': 6,
#   'pages_succeeded': 6,
#   'pages_failed': 0},
#  'created_at': '2026-09-20T12:54:42Z',
#  'updated_at': '2026-09-20T12:54:44Z',
#  '$schema': 'https://api.sarvam.ai/schemas/PublicJobBody.json'}

# %% [markdown]
# ### Get URL to download digitized text

# %%
url_obj = client.doc_ai.get_download_url(job_id=job.job_id)
print(url_obj.url)
# Out:
# https://appsprodaksharpublicsa.blob.core.windows.net/akshar-uploads/019f70c5-0df4-7797-b022-cee086d39277/019f70c5-0df9-7199-8fd0-1a413a629a06/outputs/01a0bee2-1396-7cef-bc37-7c1b79aa4a01.zip?rscd=attachment%3B+filename%3D%22feedback_notes.zip%22&se=2026-09-27T13%3A06%3A03Z&sig=AZOcp%2BQn%2F%2BalSdk0tgj4wC2rHY94URcdw9RRa1u9u5I%3D&ske=2026-09-27T13%3A06%3A03Z&skoid=ea92e965-15d8-4555-a267-7367a2169bf3&sks=b&skt=2026-09-20T13%3A05%3A53Z&sktid=d1338f9b-2c29-4ab4-b3f2-ffd01533d16f&skv=2026-06-06&sp=r&spr=https&sr=b&st=2026-09-20T13%3A05%3A53Z&sv=2026-06-06

# %% [markdown]
# ### Download Digitized Text

# %%
import requests

# %%
response = requests.get(url_obj.url)

# %%
import zipfile
import io

# %%
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_ref:
    for filename in zip_ref.namelist():
        print(filename)
# Out:
# feedback_notes.pdf/feedback_notes.md
# feedback_notes.pdf/metadata/page_001.json
# feedback_notes.pdf/metadata/page_002.json
# feedback_notes.pdf/metadata/page_003.json
# feedback_notes.pdf/metadata/page_004.json
# feedback_notes.pdf/metadata/page_005.json
# feedback_notes.pdf/metadata/page_006.json
# manifest.json

# %%
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_ref:
    with zip_ref.open('feedback_notes.pdf/feedback_notes.md', 'r') as f_in:
        markdown_notes = f_in.read()

# %% [markdown]
# ### Display Digitized Text

# %%
markdown_notes[:100]
# Out:
# b'Feedback on App\n\n1) Can the App create an experience where users feel fed connected to an actual per'

# %%
markdown_notes = markdown_notes.decode('utf-8')

# %%
from IPython.display import display, Markdown

# %%
display(Markdown(markdown_notes))
# Out:
# Feedback on App
#
# 1) Can the App create an experience where users feel fed connected to an actual persona and they are connecti interacting with a person/ persona on the other end & on every step of in the workflow? Establishing that connection upfront might improve chances of users completing the going th sustaining through the entire program as a Perhaps's - setup one of several personas acting companion are generally longer than what users want to fill out .
#
# 2) Onboarding Questionnaire is in all apps, can we make it simpler or replace the entire questionnaire with perhaps requests for 3-4 images photoz , e.g. full-length photograph of user b) photo graph of their the contents of their fridge c) photograph of their meal plates d) the room /space where they spend most of e) Their time With above, can we estimate Age Height / weight / BMI Visceral fat Dietary Preferences Exercise Patterns 23) I don't have a sense of how the app works , once after
#
# ---
#
# ...

# %% [markdown]
# ## Digitize handwritten document (Hindi)

# %%
def digitize_pdf_doc(dir_loc: str, f_name: str, language: str, output_format: str):
    pdf_data = load_document(f'{dir_loc}/{f_name}')
    job = client.doc_ai.digitise(
        file=[('output', pdf_data, 'application/pdf')],
        language=language,
        output_format=output_format,
    )
    return job.job_id

# %%
job_id = digitize_pdf_doc('./data/pdfs/', 'hindi_notes.pdf', 'hi-IN', 'md')
job_id
# Out:
# '01a0c1fd-7f0d-7ba6-be3f-df3d6d8b53ed'

# %%
import zipfile
import io

# %%
def download_and_display(job_id: str):
    job_status = client.doc_ai.get_status(job_id=job_id)
    if job_status.status != 'completed':
        return json.loads(job_status.json())

    download_url = client.doc_ai.get_download_url(job_id=job_id).url
    content = requests.get(download_url).content

    with zipfile.ZipFile(io.BytesIO(content)) as zip_ref:
        for filename in zip_ref.namelist():
            if filename.endswith('.md'):
                with zip_ref.open(filename, 'r') as f_in:
                    markdown_notes = f_in.read()
                    markdown_notes = markdown_notes.decode('utf-8')
                    display(Markdown(markdown_notes))

# %%
download_and_display(job_id)
# Out:
# classmate
#
# 11/8/2026
#
# ## झानदरि का फल
#
# ## शब्द
#
# <table>
# <thead>
# <tr>
# <th></th>
# <th>शब्द</th>
# <th>अंग्रेजी अर्थ</th>
# <th>हिंदी अर्थ</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>①</td>
# <td>लकड़द्वारा</td>
# <td>wood cutter</td>
# <td>जो जंगल में लकड़ी<br/>हो।</td>
# </tr>
# <tr>
# <td>②</td>
# <td>अचानक</td>
# <td>suddenly</td>
# <td>सकदम से, सहसा</td>
# </tr>
# <tr>
# <td>③</td>
# <td>कुल्हाड़ी</td>
# <td>Ace</td>
# <td>लकड़ी काटने का<br/>औजार</td>
# </tr>
# <tr>
# <td>④</td>
# <td>कोशिश</td>
# <td>Try, attempt</td>
# <td>प्रयास अपने आप</td>
# </tr>
# <tr>
# <td>⑤</td>
# <td>स्वयं</td>
# <td>self, oneself</td>
# <td>खुद, अपने आप</td>
# </tr>
# <tr>
# <td>⑥</td>
# <td>अंतर्ध्यान</td>
# <td>livelier, vanish</td>
# <td>अदृश्य होना,<br/>हो जाव</td>
# </tr>
# <tr>
# <td>⑦</td>
# <td>पुरस्कार</td>
# <td>Prize/award</td>
# <td>इनाम, सम्मान</td>
# </tr>
# <tr>
# <td>⑧</td>
# <td>तालाब</td>
# <td>Rond</td>
# <td>जलाशय</td>
# </tr>
# <tr>
# <td>⑨</td>
# ...
