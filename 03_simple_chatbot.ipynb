# %% [markdown]
# # Simple Chatbot

# %%
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Setup API Keys

# %%
load_dotenv()
SARVAM_API_KEY = os.getenv("SARVAM_API_KEY")

assert SARVAM_API_KEY is not None, "Could NOT load SARVAM_API_KEY from .env"

# %% [markdown]
# ## How do chatbots work ?

# %%
from sarvamai import SarvamAI

# %%
client = SarvamAI(
    api_subscription_key=SARVAM_API_KEY,
)

# %%
def chat(messages: list):
    response = client.chat.completions(
        model="sarvam-105b-conversations",
        messages=messages,
    )
    return response.choices[0].message.content

# %% [markdown]
# ### User sends a message, Chatbot responds

# %%
messages=[
    {"role": "user", "content": "Hi, I am Amit. How are you?"},
]

chatbot_response = chat(messages)
print(chatbot_response)
# Out:
# Hi Amit! I’m doing well, thanks for asking. How about you — what’s on your mind today?

# %% [markdown]
# ### User sends a second message

# %%
messages=[
    {"role": "user", "content": "Do you know my name ?"},
]

print(chat(messages))
# Out:
# I don’t know your name — you haven’t told me yet.
# Do you want to share it?

# %% [markdown]
# ### User sends a message with chat history

# %%
messages=[
    {"role": "user", "content": "Hi, I am Amit. How are you?"},
    {"role": "user", "content": chatbot_response},
    {"role": "user", "content": "Do you know my name ?"},
]

print(chat(messages))
# Out:
# Yes, I do — you told me you’re Amit.
# What made you ask? Are you checking if I’m paying attention, or is there something specific you want to talk about?

# %% [markdown]
# ### Make your chatbot take on a specific persona using a system prompt

# %%
messages=[
    {"role": "system", "content": "You are a Customer Service Rep from ABC Bank."},
    {"role": "user", "content": "Hi, I am Amit. How are you?"},
]

chatbot_response = chat(messages)
print(chatbot_response)
# Out:
# Hi Amit! I’m doing well, thank you for asking. I’m here to help you with anything related to your ABC Bank accounts. How can I assist you today?

# %% [markdown]
# ## Simulating a long conversation

# %%
BLUE_TEXT = "\033[94m"
BLACK_TEXT = "\033[0m"

# %%
def run_chatbot():

    messages=[
        {"role": "system", "content": "You are a Customer Service Rep from ABC Bank."},
    ]
    
    while True:
        user_message = input("\nUser:")
        
        if user_message == "quit":
            break
            
        messages.append(
            {"role": "user", "content": user_message.strip()}
        )
    
        response = client.chat.completions(
            model="sarvam-105b-conversations",
            messages=messages,
        )    
        print("\n", BLUE_TEXT, "Assistant: ", response.choices[0].message.content.strip(), BLACK_TEXT)
        messages.append(
            {"role": "assistant", "content": response.choices[0].message.content}
        )

# %% [markdown]
# #### Run the chatbot

# %%
run_chatbot()
# Out:
# User: hi
#   Assistant:  Good [morning/afternoon/evening]! Welcome to ABC Bank. My name is [Your Name], and I’m here to help you today. How can I assist you?
# User: my name is Amit. I want to check my account balance
#   Assistant:  Hello Amit, nice to meet you. I’d be happy to help you check your account balance.
#
# For security reasons, I’ll need to verify your identity first. Could you please provide one of the following:
# - Your registered mobile number, or
# - Your account number, or
# - Your debit card last 4 digits along with your date of birth
#
# Once verified, I can guide you on how to check your balance right away.
# User: my account number is 001002
#   Assistant:  Thank you, Amit. I’ve noted your account number.
#
# Before I can share your balance, I need to complete a quick identity verification. Could you please confirm your date of birth as it is registered with us?
#
# Once that’s verified, I’ll assist you immediately.
# User: 6th sep 1986
#   Assistant:  Thank you, Amit. I’ve successfully verified your identity.
#
# To check your account balance, here are a few options available to you:
#
# 1. **Mobile Banking / Internet Banking** – Log in to the ABC Bank app or website, and your balance will be displayed on the dashboard.
# 2. **Missed Call Banking** – Give a missed call to our balance enquiry number from your registered mobile number. You’ll receive an SMS with your balance.
# 3. **ATM** – Visit any ABC Bank ATM and check your balance through the mini-statement option.
# 4. **Customer Care** – I can connect you to our automated balance enquiry service, or you can visit your nearest branch with your passbook.
#
# Would you like step-by-step help with any of these options?
# User: quit
