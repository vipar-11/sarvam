# %% [markdown]
# # Language Processing

# %%
from sarvamai import SarvamAI

# %%
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Setup API Keys

# %%
load_dotenv()
SARVAM_API_KEY = os.getenv('SARVAM_API_KEY')

# %%
client = SarvamAI(api_subscription_key=SARVAM_API_KEY)

# %% [markdown]
# ## Detect Language

# %%
#text = "Hello my friend. How are you doing ?"
#text = "Mera refund status check karo"
text = "नमस्ते, आप कैसे हैं?"

# %%
response = client.text.identify_language(
    input=text
)

# %%
detected_language, detected_script = response.language_code, response.script_code
detected_language, detected_script
# Out:
# ('hi-IN', 'Deva')

# %% [markdown]
# ## Translate to English

# %%
response = client.text.translate(
    input=text,
    source_language_code=detected_language,
    target_language_code="en-IN",
    # speaker_gender="Male"
)

# %%
translated_text = response.translated_text
translated_text
# Out:
# 'Hello, how are you?'

# %% [markdown]
# ## Translate Back to Hindi

# %%
response = client.text.translate(
    input=translated_text,
    source_language_code="en-IN",
    target_language_code="hi-IN",
    speaker_gender="Male"
)
response.translated_text
# Out:
# 'नमस्ते, आप कैसे हैं?'

# %%
response = client.text.translate(
    input=translated_text,
    source_language_code="en-IN",
    target_language_code="hi-IN",
    speaker_gender="Female",
    model="mayura:v1",
    mode="modern-colloquial",
)
response.translated_text
# Out:
# 'Hello, कैसे हो?'

# %%
response = client.text.translate(
    input="Please come my sister-in-law (husband's sister)",
    source_language_code="en-IN",
    target_languag
    e_code="ta-IN",
    speaker_gender="Male",
    model="mayura:v1",
    mode="classic-colloquial",    
)
response.translated_text
# Out:
# 'எங்க அண்ணன் வீட்டு பொண்டாட்டிய கொஞ்சம் வாங்க'
