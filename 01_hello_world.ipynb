# %% [markdown]
# # Hello World

# %%
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Setup API Keys

# %%
load_dotenv()
SARVAM_API_KEY = os.getenv('SARVAM_API_KEY')

assert SARVAM_API_KEY is not None, 'Could NOT load SARVAM_API_KEY from .env'

# %% [markdown]
# ## Make your first API Call

# %%
from sarvamai import SarvamAI

# %%
client = SarvamAI(
    api_subscription_key=SARVAM_API_KEY,
)

response = client.chat.completions(
    model="sarvam-105b-conversations",
    messages=[
        {"role": "user", "content": "Hi, How are you?"},
    ],
)
print(response.choices[0].message.content)
# Out:
# Hi! I’m doing well, thanks for asking. How about you — what’s on your mind today?

# %% [markdown]
# ### Review the structure of the response

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "20260924_6d415d96-88df-4d4a-9b49-b9995f203962",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "Hi! I’m doing well, thanks for asking. How about you — what’s on your mind today?",
#         "role": "assistant",
#         "refusal": null,
#         "reasoning_content": null,
#         "tool_calls": null
#       },
#       "logprobs": null
#     }
#   ],
#   "created": 1790271540,
#   "model": "sarvam-105b-conversations",
#   "object": "chat.completion",
#   "system_fingerprint": "vllm-0.29.1rc1.dev145+gfe61f3317-9c902b0a",
#   "usage": {
#     "completion_tokens": 25,
#     "prompt_tokens": 20,
#     "total_tokens": 45,
#     "completion_tokens_details": null,
#     "prompt_tokens_details": null
#   },
#   "service_tier": null
# }
