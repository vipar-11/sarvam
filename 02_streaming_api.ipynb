# %% [markdown]
# # Showcasing Streaming Responses

# %%
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Setup API Keys

# %%
load_dotenv()
SARVAM_API_KEY = os.getenv('SARVAM_API_KEY')

assert SARVAM_API_KEY is not None, 'Could NOT load SARVAM_API_KEY from .env'

# %% [markdown]
# ## Long answers without streaming

# %%
from sarvamai import SarvamAI

client = SarvamAI(
    api_subscription_key=SARVAM_API_KEY,
)

# %%
response = client.chat.completions(
    model="sarvam-105b-conversations",
    messages=[
        {"role": "user", "content": "Tell me about Sarvam AI"},
    ],
)
print(response.choices[0].message.content)
# Out:
# Sarvam AI is a Bengaluru-based artificial intelligence company founded in August 2023 by **Dr. Vivek Raghavan** and **Dr. Pratyush Kumar**. Its focus is on building **sovereign large language models (LLMs)** that work fluently in **English and all 22 official Indian languages**, trained from scratch rather than fine-tuned from existing foreign models.
#
# The company’s work is guided by the **IndiaAI Mission**, which aims to create AI infrastructure that is open-source, multilingual, and tailored to India’s linguistic and cultural needs. Sarvam AI’s models are designed to handle **native scripts, transliteration, and code-mixed speech**—the way many Indians actually communicate in daily life.
#
# Its flagship product is **Sarvam-1**, a 2B-parameter foundation model trained entirely from scratch for English and 10 Indian languages, with strong performance on reasoning and multilingual tasks. Beyond this, Sarvam AI offers:
#
# - **Speech-to-Text (Saarika)** – Converts speech into text in English and 10 Indian languages, with high accuracy for Indian accents and multi-speaker handling.
# - **Speech-to-Text Translate (Saaras)** – Directly transcribes speech into English text from 10 Indian languages.
# - **Text-to-Speech (Bulbul)** – Generates natural-sounding speech in English and 10 Indian languages, with customizable voice parameters.
# - **Translation (Mayura)** – Translates between English and 10 Indian languages with customizable styles (formal, colloquial, script control).
# - **Translation (Sarvam-Translate)** – Supports all 22 official Indian languages, optimized for formal and structured text.
# - **Chat & Reasoning (Sarvam-M)** – A multilingual, hybrid-reasoning model based on Mistral-Small, post-trained for superior reasoning and Indic language support.
# - **Conversational Voice Agents (Samvaad)** – Voice-based AI agents tuned for Indian accents and dialects, used in customer service and engagement.
# - **Foundation Model (Sarvam-1 & Sarvam’s AI Assistant)** – General-purpose LLMs for multilingual reasoning and generation.
#
# Sarvam AI is notable for **open-sourcing its models**—making them available for developers and researchers—and for building **voice-first AI products** that address the realities of Indian communication, where speech, regional languages, and mixed scripts dominate.
#
# If you want, I can also break down how its technology differs from global AI models or explain what “sovereign AI” means in practice. Would you like that?

# %% [markdown]
# ## Long answers with streaming

# %%
stream = client.chat.completions(
    model="sarvam-105b-conversations",
    messages=[
        {"role": "user", "content": "Tell me about Sarvam AI"},
    ],
    stream=True
)

for chunk in stream:
    if chunk.choices and chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end="", flush=True)
# Out:
# Sarvam AI is a Bengaluru-based artificial intelligence company founded by **Dr. Vivek Raghavan** and **Dr. Pratyush Kumar**. It was selected under the **IndiaAI Mission** to build a **sovereign large language model** that supports **all 22 official Indian languages**, as well as English, with strong reasoning and voice capabilities.
#
# **What they focus on:**
# • **Multilingual AI** – Models trained from scratch to understand and generate text in Indian languages, not just translate from English.
# • **Voice & Conversational AI** – Speech-to-text, text-to-speech, and chatbots tuned for Indian accents and dialects.
# • **Open-source contributions** – Releasing models and datasets publicly to encourage innovation.
# • **Enterprise solutions** – Tools like *Samvaad* for customer service voice agents and *Studio* for content creation, designed for Indian contexts.
#
# **Key products:**
# - **Sarvam-1** – A foundation model trained from scratch for English + 10 Indian languages.
# - **Sarvam’s AI Assistant** – This is me; I’m part of their multilingual, reasoning-focused family.
# - **Saarika** – Speech-to-text for English + 10 Indian languages.
# - **Bulbul** – Text-to-speech with natural prosody.
# - **Samvaad** – Voice-based AI agents for customer engagement.
# - **Studio** – End-to-end content generation for Indian languages.
# - **Sarvam-M** – A multilingual chat/reasoning model post-trained for better Indic language performance.
#
# **Why it matters:**
# Sarvam AI’s work is aimed at making advanced AI accessible and culturally relevant for India, rather than relying solely on foreign models. Their emphasis is on *Vasudhaiva Kutumbakam*—technology that serves globally but is rooted in local needs.
#
# If you want, I can also walk you through their **technical architecture** or **funding and partnerships** in detail. Would you like that next?

# %% [markdown]
# ### Review structure of each chunk in the stream

# %%
stream = client.chat.completions(
    model="sarvam-105b-conversations",
    messages=[
        {"role": "user", "content": "Tell me about Sarvam AI"},
    ],
    stream=True
)

# %% [markdown]
# #### First Chunk

# %%
chunk = next(stream)

# %%
print(chunk.model_dump_json(indent=2))
# Out:
# {
#   "id": "20260923_f31073e1-1920-49bb-87f5-937c37dffb7e",
#   "choices": [
#     {
#       "delta": {
#         "content": "",
#         "role": "assistant",
#         "refusal": null,
#         "function_call": null,
#         "tool_calls": null
#       },
#       "index": 0,
#       "finish_reason": null,
#       "logprobs": null
#     }
#   ],
#   "created": 1790160095,
#   "model": "sarvam-105b-conversations",
#   "object": "chat.completion.chunk",
#   "service_tier": null,
#   "system_fingerprint": null,
#   "usage": null,
#   "prompt_token_ids": null,
#   "prompt_text": null
# }

# %% [markdown]
# #### Second Chunk

# %%
chunk = next(stream)

# %%
print(chunk.model_dump_json(indent=2))
# Out:
# {
#   "id": "20260923_f31073e1-1920-49bb-87f5-937c37dffb7e",
#   "choices": [
#     {
#       "delta": {
#         "content": "Sar",
#         "refusal": null,
#         "role": null,
#         "function_call": null,
#         "tool_calls": null
#       },
#       "index": 0,
#       "finish_reason": null,
#       "logprobs": null,
#       "token_ids": null
#     }
#   ],
#   "created": 1790160095,
#   "model": "sarvam-105b-conversations",
#   "object": "chat.completion.chunk",
#   "service_tier": null,
#   "system_fingerprint": null,
#   "usage": null
# }

# %% [markdown]
# #### Third Chunk

# %%
chunk = next(stream)

# %%
print(chunk.model_dump_json(indent=2))
# Out:
# {
#   "id": "20260923_f31073e1-1920-49bb-87f5-937c37dffb7e",
#   "choices": [
#     {
#       "delta": {
#         "content": "vam AI is a Bengaluru",
#         "refusal": null,
#         "role": null,
#         "function_call": null,
#         "tool_calls": null
#       },
#       "index": 0,
#       "finish_reason": null,
#       "logprobs": null,
#       "token_ids": null
#     }
#   ],
#   "created": 1790160095,
#   "model": "sarvam-105b-conversations",
#   "object": "chat.completion.chunk",
#   "service_tier": null,
#   "system_fingerprint": null,
#   "usage": null
# }
