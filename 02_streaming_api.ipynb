# %% [markdown]
# # Showcasing Streaming Responses

# %%
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Setup API Keys

# %%
load_dotenv()
SARVAM_API_KEY = os.getenv('SARVAM_API_KEY')

assert SARVAM_API_KEY is not None, 'Could NOT load SARVAM_API_KEY from .env'

# %% [markdown]
# ## Long answers without streaming

# %%
from sarvamai import SarvamAI

client = SarvamAI(
    api_subscription_key=SARVAM_API_KEY,
)

# %%
response = client.chat.completions(
    model="sarvam-105b-conversations",
    messages=[
        {"role": "user", "content": "Tell me about Sarvam AI"},
    ],
)
print(response.choices[0].message.content)
# Out:
# Sarvam AI is a Bengaluru-based artificial intelligence company focused on building large language models and AI systems that work fluently across India’s languages and contexts. Founded by **Dr. Vivek Raghavan** and **Dr. Pratyush Kumar**, the company was selected under the Government of India’s **IndiaAI Mission** to develop a sovereign large language model that supports all 22 official Indian languages, is open-sourced, and can work with voice and reasoning capabilities.
#
# Sarvam AI’s products include:
# - **Foundation Models**: Trained from scratch for English and all 22 Indian languages, with capabilities in reasoning and multilingual dialogue.
# - **Speech-to-Text (Saarika)**: Converts speech to text in multiple Indian languages, optimized for telephony and noisy environments.
# - **Speech-to-Text Translate (Saaras)**: Directly translates speech into English text.
# - **Text-to-Speech (Bulbul)**: Generates natural-sounding speech from text, with voice customization.
# - **Translation (Mayura)**: High-quality translation between English and Indian languages with style and script control.
# - **Chat & Reasoning (Sarvam-M)**: A multilingual, hybrid-reasoning model built on Mistral-Small.
# - **Conversational Voice Agents (Samvaad)**: Voice-based AI agents for customer service, tuned for Indian accents and dialects.
# - **Sarvam-1**: A 2B-parameter foundation model trained entirely from scratch for English and 10 Indian languages.
#
# The company’s mission is to make AI truly accessible to India’s diverse linguistic and cultural landscape, ensuring that technology serves people in their native languages rather than forcing them into English-only interfaces.
#
# If you want, I can also walk you through their funding history, technical architecture, or how they compare to global AI companies. Would you like that?

# %% [markdown]
# ## Long answers with streaming

# %%
stream = client.chat.completions(
    model="sarvam-105b-conversations",
    messages=[
        {"role": "user", "content": "Tell me about Sarvam AI"},
    ],
    stream=True
)

for chunk in stream:
    if chunk.choices and chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end="", flush=True)
# Out:
# Sarvam AI is a Bengaluru-based artificial intelligence company that focuses on building **large language models (LLMs)** and related AI systems tailored for **India’s languages and contexts**. It was founded by **Dr. Vivek Raghavan** and **Dr. Pratyush Kumar** in 2023, with a mission to create AI that is sovereign, multilingual, and capable of serving both domestic and global needs.
#
# ### What they do
# Sarvam AI develops:
# - **Foundation models** trained from scratch for English and all 22 official Indian languages.
# - **Speech-to-text** systems for Indian languages, including models like *Saarika* (speech-to-text) and *Saaras* (speech-to-text with translation).
# - **Text-to-speech** solutions such as *Bulbul* (natural voice synthesis).
# - **Translation and reasoning models** like *Mayura* (advanced translation) and *Sarvam-M* (multilingual reasoning).
# - **Conversational AI** agents for customer service and engagement, built on their own models.
#
# Their work is aligned with the **IndiaAI Mission**, which aims to develop a sovereign LLM that supports all official Indian languages, open-sourced, and built with local infrastructure.
#
# ### Key products
# Some of their publicly available products:
# - **Sarvam-1** – a 2B-parameter foundation model trained from scratch for English + 10 Indian languages.
# - **Sarvam’s AI Assistant** (that’s me) – a text-only multilingual assistant trained from scratch, supporting English and all 22 official Indian languages.
# - **Saarika** – high-accuracy speech-to-text with domain-aware transcription, multi-speaker handling, and telephony optimization.
# - **Saaras** – speech-to-text with direct translation into English.
# - **Bulbul** – text-to-speech with natural prosody, customizable voice parameters.
# - **Mayura** – advanced translation between English and select Indian languages with style and script control.
# - **Sarvam-M** – multilingual, hybrid-reasoning model post-trained for better reasoning.
#
# ### Why it matters
# Sarvam AI’s focus is on **language inclusion**—ensuring that AI systems can work fluently in India’s diverse linguistic landscape, not just English. Their models are designed to handle:
# - Multiple scripts (Devanagari, Roman, etc.)
# - Code-mixed speech and text (common in India)
# - Regional accents and dialects
# - Domain-specific vocabulary (e.g., agriculture, healthcare, finance)
#
# They also emphasize **open-sourcing** certain models, so developers and researchers can build on them.
#
# ### Funding and scale
# Sarvam AI raised **$41 million in Series A funding** in December 2023, led by **Lightspeed**, **Peak XV Partners**, and **Khosla Ventures**. This funding supports scaling up compute infrastructure, expanding language coverage, and improving model performance.
#
# ### Website
# For official details, product documentation, and API access: [https://www.sarvam.ai](https://www.sarvam.ai)
#
# If you want, I can also break down **how their multilingual models are trained** or compare them with global AI providers. Which angle would you like to explore?
